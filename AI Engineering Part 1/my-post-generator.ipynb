# %% [markdown]
# ### Step1: Import Libraries and API Keys

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display, Markdown

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")

# %% [markdown]
# ### Step 2: Searching the web

# %%
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini-search-preview-2025-03-11",
    messages=[
        {"role": "user", "content": "What is today's date? Tell me the 3 top stories About Global warming in this past week, according to reliable news media. Each story shoube be from a seperate source followed with the link and date. Include dates"}
    ],
    max_tokens=500
)

# %%
search_results = completion.choices[0].message.content
display(Markdown(search_results))
# Out:
# Today's date is Friday, March 27, 2026.
#
# Here are three top stories about global warming from the past week, each from a separate reliable news source:
#
# 1. **"Intensifying global heat threatens livability for younger and older adults"**
#    A study published on March 10, 2026, in *Environmental Research: Health* highlights the escalating risks of heat and humidity on human health, particularly affecting younger and older populations. The research underscores the urgent need for adaptive strategies to mitigate these health threats.
#
# 2. **"Quantifying climate loss and damage consistent with a social cost of carbon"**
#    On March 25, 2026, *Nature* published a study estimating that carbon dioxide emissions from 1990 through 2020 caused $10.2 trillion in cumulative damages by 2020 in the U.S., with about 30% occurring within the country. The study emphasizes the substantial economic impact of past emissions and the need for comprehensive climate policies.
#
# ...

# %% [markdown]
# ### Step 3: Summarize and write social media post

# %%
system_message = """
You are a helpful assistant who creates amazing linkedin posts about AI based on text that you are provided
with source hyperlinks. Make the posts engaging and interesting. Also make concise and add a thought provoking at the end to encourage comments."""
prompt = f"""
The following text contains top3 news stories about Global warming from the past week.
Now Please write my linkedin post based on this information.
{search_results}

"""
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role":"system", "content": system_message},
        {"role":"user", "content": prompt}

    ],
    max_tokens=500,
    temperature=0.7,
)
chat_response = completion.choices[0].message.content
display(Markdown(chat_response))
# Out:
# 🌍 **The Alarming Acceleration of Global Warming: Key Insights from Recent Research** 🌡️
#
# As of March 24, 2026, three enlightening studies have emerged, painting a stark picture of our planet's changing climate:
#
# 1. **Accelerated Global Warming**
#    A recent study from *Geophysical Research Letters* reveals that global warming has accelerated significantly from 2015 to 2025, with over 98% confidence that this decade has seen the most rapid increase yet. [Read more](https://en.wikipedia.org/wiki/2026_in_climate_change?utm_source=openai).
#
# 2. **Droughts and Heatwaves on the Rise**
#    Research published in *Science Advances* indicates that compound drought-heatwave events have surged nearly eightfold since the early 2000s, highlighting alarming regional variations in their frequency. [Explore the details](https://en.wikipedia.org/wiki/2026_in_climate_change?utm_source=openai).
#
# 3. **Heat Threats to Vulnerable Populations**
# ...
