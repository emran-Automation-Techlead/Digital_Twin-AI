# %% [markdown]
# ### Step 1: Import Libraries and load to the enviroment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY") 
if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
   print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role":"user", "content":"make it 5 lines talk about amazon rain forest"}]
)

answer = response.choices[0].message.content
print(answer)
# Out:
# The Amazon Rainforest is the largest tropical rainforest in the world, covering much of northern South America. It is home to an incredible diversity of plants, animals, and insects, many of which are found nowhere else on Earth. The rainforest plays a crucial role in regulating the global climate by absorbing large amounts of carbon dioxide. It also provides vital resources and livelihoods for indigenous communities living within it. However, the Amazon faces threats from deforestation and climate change, making conservation efforts essential.
